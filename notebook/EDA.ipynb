# %%
import pandas as pd
import plotly.express as px

# %%
irrigation_data = pd.read_csv('../irrigation_machine.csv')

# %%
fig = px.histogram(irrigation_data, x="sensor_1")
fig.show()

# %%
fig2 = px.scatter(irrigation_data, x="sensor_1", y=irrigation_data.index)
fig2.show()
